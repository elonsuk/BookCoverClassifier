# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
assert tf.__version__.startswith('2')
from tensorflow import keras
from tensorflow.keras import layers

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
IMAGE_PATH = r"C:\Users\offco\Documents\Dev_Projects\BookCoverClassifier\Datasets\Test_Run\Test_Augment"
IMAGE_SIZE = (256, 256)
BATCH_SIZE = 32
NUM_CLASSES = 5

train = tf.keras.preprocessing.image_dataset_from_directory(
    IMAGE_PATH,
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
train = train.map(lambda x, y: (x, tf.one_hot(y, depth=NUM_CLASSES)))

validation = tf.keras.preprocessing.image_dataset_from_directory(
    IMAGE_PATH,
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE
)
validation = validation.map(lambda x, y: (x, tf.one_hot(y, depth=NUM_CLASSES)))
# Out:
# Found 254 files belonging to 5 classes.
# Using 204 files for training.
# Found 254 files belonging to 5 classes.
# Using 50 files for validation.

# %%
plt.figure(figsize=(10, 10))
for images, labels in train.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(str(labels[i].numpy()))
        plt.axis("off")

# %%
train = train.prefetch(buffer_size=32)
validation = validation.prefetch(buffer_size=32)

# %%
def make_model(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.Conv2D(32, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    activation = "softmax"
    units = num_classes

    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)

# %%
model = make_model(input_shape=IMAGE_SIZE + (3, ), num_classes=5)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['rescaling[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  18496       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 128, 128, 64  0           ['activation_1[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 128, 128, 12  8896       ['activation_2[0][0]']
#  v2D)                           8)
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 12  512        ['separable_conv2d[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 128, 128, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  separable_conv2d_1 (SeparableC  (None, 128, 128, 12  17664      ['activation_3[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['separable_conv2d_1[0][0]']
#  rmalization)                   8)
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  8320        ['activation_1[0][0]']
#
#  add (Add)                      (None, 64, 64, 128)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 64, 64, 256)  34176      ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 256)  1024       ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 256)  0           ['batch_normalization_4[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 64, 64, 256)  68096      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 256)  33024       ['add[0][0]']
#
#  add_1 (Add)                    (None, 32, 32, 256)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 256)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 32, 32, 512)  133888     ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 512)  2048       ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 32, 32, 512)  0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 32, 32, 512)  267264     ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 512)  2048       ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 512)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 16, 16, 512)  131584      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 16, 16, 512)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 512)  0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 16, 16, 728)  378072     ['activation_8[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 728)  2912       ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 16, 16, 728)  0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 16, 16, 728)  537264     ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 728)  2912       ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 728)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 728)    373464      ['add_2[0][0]']
#
#  add_3 (Add)                    (None, 8, 8, 728)    0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 8, 8, 1024)  753048      ['add_3[0][0]']
#  onv2D)
#
#  batch_normalization_10 (BatchN  (None, 8, 8, 1024)  4096        ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 8, 8, 1024)   0           ['batch_normalization_10[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['activation_10[0][0]']
#  alAveragePooling2D)
#
#  dropout (Dropout)              (None, 1024)         0           ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense (Dense)                  (None, 5)            5125        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 2,786,749
# Trainable params: 2,778,013
# Non-trainable params: 8,736
# __________________________________________________________________________________________________

# %%
epochs = 50

callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="binary_crossentropy",
    metrics=["accuracy"],
)
model.fit(
    train, epochs=epochs, callbacks=callbacks, validation_data=validation,
)
# Out:
# Epoch 1/50
# 7/7 [==============================] - 376s 38s/step - loss: 0.2745 - accuracy: 0.8333 - val_loss: 0.6732 - val_accuracy: 0.1600
# Epoch 2/50
# 7/7 [==============================] - 523s 77s/step - loss: 0.0355 - accuracy: 0.9902 - val_loss: 0.6541 - val_accuracy: 0.1600
# Epoch 3/50
# 7/7 [==============================] - 568s 73s/step - loss: 0.0099 - accuracy: 1.0000 - val_loss: 0.6373 - val_accuracy: 0.1600
# Epoch 4/50
# 7/7 [==============================] - 576s 83s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.6228 - val_accuracy: 0.1600
# Epoch 5/50
# 7/7 [==============================] - 476s 61s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.6100 - val_accuracy: 0.1600
# Epoch 6/50
# 7/7 [==============================] - 544s 79s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.5985 - val_accuracy: 0.1600
# Epoch 7/50
# 7/7 [==============================] - 569s 86s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5885 - val_accuracy: 0.1600
# Epoch 8/50
# 7/7 [==============================] - 501s 67s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.5793 - val_accuracy: 0.1600
# Epoch 9/50
# 7/7 [==============================] - 629s 89s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.1600
# Epoch 10/50
# 7/7 [==============================] - 513s 68s/step - loss: 0.0288 - accuracy: 0.9706 - val_loss: 0.5627 - val_accuracy: 0.1600
# Epoch 11/50
# 7/7 [==============================] - 565s 82s/step - loss: 0.0532 - accuracy: 0.9559 - val_loss: 0.5605 - val_accuracy: 0.2800
# Epoch 12/50
# 7/7 [==============================] - 443s 51s/step - loss: 0.0731 - accuracy: 0.9314 - val_loss: 0.5661 - val_accuracy: 0.1600
# Epoch 13/50
# 7/7 [==============================] - 96s 15s/step - loss: 0.0383 - accuracy: 0.9706 - val_loss: 0.5665 - val_accuracy: 0.1600
# Epoch 14/50
# 7/7 [==============================] - 129s 20s/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.5363 - val_accuracy: 0.4400
# Epoch 15/50
# 7/7 [==============================] - 144s 19s/step - loss: 0.0115 - accuracy: 0.9951 - val_loss: 0.5190 - val_accuracy: 0.4400
# Epoch 16/50
# 7/7 [==============================] - 141s 20s/step - loss: 0.0287 - accuracy: 0.9755 - val_loss: 0.5041 - val_accuracy: 0.4400
# Epoch 17/50
# 7/7 [==============================] - 100s 13s/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5331 - val_accuracy: 0.3400
# Epoch 18/50
# 7/7 [==============================] - 120s 17s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5512 - val_accuracy: 0.3200
# Epoch 19/50
# 7/7 [==============================] - 136s 19s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.5716 - val_accuracy: 0.3200
# Epoch 20/50
# 7/7 [==============================] - 131s 20s/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5971 - val_accuracy: 0.3200
# Epoch 21/50
# 7/7 [==============================] - 104s 13s/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.6240 - val_accuracy: 0.3200
# Epoch 22/50
# 7/7 [==============================] - 143s 22s/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.6421 - val_accuracy: 0.3000
# Epoch 23/50
# 7/7 [==============================] - 131s 17s/step - loss: 0.0120 - accuracy: 0.9951 - val_loss: 0.6500 - val_accuracy: 0.2800
# Epoch 24/50
# 7/7 [==============================] - 131s 19s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.7017 - val_accuracy: 0.2800
# Epoch 25/50
# 7/7 [==============================] - 103s 13s/step - loss: 0.0114 - accuracy: 0.9853 - val_loss: 0.7063 - val_accuracy: 0.2800
# Epoch 26/50
# 7/7 [==============================] - 115s 17s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.7019 - val_accuracy: 0.2800
# Epoch 27/50
# 7/7 [==============================] - 132s 18s/step - loss: 0.0097 - accuracy: 0.9951 - val_loss: 0.7280 - val_accuracy: 0.2800
# Epoch 28/50
# 7/7 [==============================] - 126s 16s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7630 - val_accuracy: 0.2800
# Epoch 29/50
# 7/7 [==============================] - 88s 13s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7974 - val_accuracy: 0.2800
# Epoch 30/50
# 7/7 [==============================] - 148s 21s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.8227 - val_accuracy: 0.2800
# Epoch 31/50
# 7/7 [==============================] - 128s 17s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.8455 - val_accuracy: 0.2800
# Epoch 32/50
# 7/7 [==============================] - 108s 15s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.8543 - val_accuracy: 0.2800
# Epoch 33/50
# 7/7 [==============================] - 181s 23s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.8678 - val_accuracy: 0.2800
# Epoch 34/50
# 7/7 [==============================] - 120s 16s/step - loss: 8.8184e-04 - accuracy: 1.0000 - val_loss: 0.8828 - val_accuracy: 0.2800
# Epoch 35/50
# 7/7 [==============================] - 129s 18s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.9049 - val_accuracy: 0.2800
# Epoch 36/50
# 7/7 [==============================] - 166s 24s/step - loss: 3.0966e-04 - accuracy: 1.0000 - val_loss: 0.9238 - val_accuracy: 0.2800
# Epoch 37/50
# 7/7 [==============================] - 132s 19s/step - loss: 5.6263e-04 - accuracy: 1.0000 - val_loss: 0.9426 - val_accuracy: 0.3000
# Epoch 38/50
# 7/7 [==============================] - 94s 14s/step - loss: 3.0420e-04 - accuracy: 1.0000 - val_loss: 0.9588 - val_accuracy: 0.3200
# Epoch 39/50
# 7/7 [==============================] - 99s 14s/step - loss: 1.8372e-04 - accuracy: 1.0000 - val_loss: 0.9760 - val_accuracy: 0.3400
# Epoch 40/50
# 7/7 [==============================] - 146s 21s/step - loss: 2.9438e-04 - accuracy: 1.0000 - val_loss: 0.9951 - val_accuracy: 0.3600
# Epoch 41/50
# 7/7 [==============================] - 121s 17s/step - loss: 3.2474e-04 - accuracy: 1.0000 - val_loss: 1.0129 - val_accuracy: 0.3600
# Epoch 42/50
# 7/7 [==============================] - 161s 25s/step - loss: 5.9215e-04 - accuracy: 1.0000 - val_loss: 1.0294 - val_accuracy: 0.4000
# Epoch 43/50
# 7/7 [==============================] - 118s 16s/step - loss: 3.4158e-04 - accuracy: 1.0000 - val_loss: 1.0386 - val_accuracy: 0.4400
# Epoch 44/50
# 7/7 [==============================] - 123s 19s/step - loss: 6.8882e-04 - accuracy: 1.0000 - val_loss: 1.0502 - val_accuracy: 0.4400
# Epoch 45/50
# 7/7 [==============================] - 124s 18s/step - loss: 1.2898e-04 - accuracy: 1.0000 - val_loss: 1.0622 - val_accuracy: 0.4400
# Epoch 46/50
# 7/7 [==============================] - 101s 14s/step - loss: 2.8224e-04 - accuracy: 1.0000 - val_loss: 1.0774 - val_accuracy: 0.4400
# Epoch 47/50
# 7/7 [==============================] - 139s 20s/step - loss: 1.9458e-04 - accuracy: 1.0000 - val_loss: 1.0878 - val_accuracy: 0.4400
# Epoch 48/50
# 7/7 [==============================] - 122s 18s/step - loss: 4.1361e-04 - accuracy: 1.0000 - val_loss: 1.0979 - val_accuracy: 0.4400
# Epoch 49/50
# 7/7 [==============================] - 100s 12s/step - loss: 2.8721e-04 - accuracy: 1.0000 - val_loss: 1.1065 - val_accuracy: 0.4400
# Epoch 50/50
# 7/7 [==============================] - 139s 19s/step - loss: 3.0104e-04 - accuracy: 1.0000 - val_loss: 1.1168 - val_accuracy: 0.4400

# %%
IMG_PATH = r"C:\Users\offco\Documents\Dev_Projects\BookCoverClassifier\Datasets\Test_Run\Predict_Images\Harry_Potter_and_the_Half_Blood_Prince\1.Harry_Potter_and_the_Half_Blood_Prince.jpg"

img = keras.preprocessing.image.load_img(
    IMG_PATH, 
    target_size=IMAGE_SIZE
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
score = predictions[0]
print(np.where(score == score.max()))
# Out:
# (array([1], dtype=int64),)

# %%
SAVE_PATH = r"C:\Users\offco\Documents\Dev_Projects\BookCoverClassifier\Test_Run\Model"
model.save(SAVE_PATH)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\offco\Documents\Dev_Projects\BookCoverClassifier\Test_Run\Model\assets
